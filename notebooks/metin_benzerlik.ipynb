# %%
# !pip install nltk gensim scikit-learn pandas numpy matplotlib
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
import nltk
import pandas as pd
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# Requirement already satisfied: nltk in c:\users\eren\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: gensim in c:\users\eren\anaconda3\lib\site-packages (4.3.3)
# Requirement already satisfied: scikit-learn in c:\users\eren\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: pandas in c:\users\eren\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\eren\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\eren\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\eren\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\eren\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\eren\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\eren\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\eren\anaconda3\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\eren\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\eren\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\eren\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eren\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\eren\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eren\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\eren\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eren\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\eren\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\eren\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\eren\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\eren\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\eren\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\eren\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')

# Birleştirilmiş dosyayı yükle
df = pd.read_csv("cleaned_descriptions.csv")

# Metinleri birleştir ve temizle
all_text = " ".join(df["description"].astype(str).tolist()).lower()
tokens = word_tokenize(all_text)
tokens = [token for token in tokens if token.isalpha()]  # sadece harflerden oluşan kelimeler

# Frekansları say
word_freq = Counter(tokens)
sorted_freq = sorted(word_freq.values(), reverse=True)

# Log-log grafiği (Zipf)
ranks = np.arange(1, len(sorted_freq) + 1)
frequencies = np.array(sorted_freq)

plt.figure(figsize=(8,6))
plt.loglog(ranks, frequencies, marker=".")
plt.title("Zipf Yasası Log-Log Grafiği - Birleşik Açıklamalar")
plt.xlabel("Kelime Sırası (Rank)")
plt.ylabel("Kelime Frekansı (Frequency)")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.tight_layout()
plt.show()

# Veri boyutu bilgisi
print(f"Toplam belge sayısı: {len(df)}")
print(f"Eşsiz kelime sayısı: {len(word_freq)}")
print(f"Toplam kelime sayısı: {len(tokens)}")

if len(tokens) < 1000:
    print("Veri seti küçük sayılır. Zipf analizi sınırlı bilgi sağlayabilir.")
else:
    print("Veri seti Zipf analizi için yeterlidir.")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Toplam belge sayısı: 297
# Eşsiz kelime sayısı: 228
# Toplam kelime sayısı: 1617
# Veri seti Zipf analizi için yeterlidir.

# %%
df_birlesik = df.dropna()
df_birlesik = df.reset_index(drop=True)

# İlk 5 veri örneği
df_birlesik.head()
# Out:
#                                          description
# 0  MAJOR SMALL & LARGE BOWEL PROCEDURES WITH COMP...
# 1  PERCUTANEOUS CARDIOVASCULAR PROCEDURES WITHOUT...
# 2  DENTAL & ORAL DIS EXCEPT EXTRACTIONS & RESTORA...
# 3                 CRANIOTOMY AGE > EXCEPT FOR TRAUMA
# 4  DISORDERS OF LIVER EXCEPT MALIGNANCY, CIRRHOSI...

# %%
# Lowercasing ve HTML/Özel Karakter Temizliği
import re
from bs4 import BeautifulSoup

def clean_text(text):
    # HTML etiketlerini kaldır (gerekirse)
    text = BeautifulSoup(text, "html.parser").get_text()
    # Özel karakterleri kaldır
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)
    # Küçük harfe çevir
    return text.lower()

df_birlesik["cleaned"] = df_birlesik["description"].apply(clean_text)

# Örnek dönüşüm
print("Örnek orijinal metin:\n", df_birlesik["description"].iloc[0])
print("\nTemizlenmiş:\n", df_birlesik["cleaned"].iloc[0])
# Out:
# Örnek orijinal metin:
#  MAJOR SMALL & LARGE BOWEL PROCEDURES WITH COMPLICATIONS, COMORBIDITIES
#
# Temizlenmiş:
#  major small  large bowel procedures with complications comorbidities
# C:\Users\eren\AppData\Local\Temp\ipykernel_11064\3343909114.py:7: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, "html.parser").get_text()

# %%
# Tokenization ve Noktalama İşareti Kaldırma
from nltk.tokenize import word_tokenize
import string

def tokenize(text):
    tokens = word_tokenize(text)
    tokens = [t for t in tokens if t.isalpha()]  # sadece alfabetik kelimeler
    return tokens

df_birlesik["tokens"] = df_birlesik["cleaned"].apply(tokenize)

# Örnek
print("Tokenized örnek:", df_birlesik["tokens"].iloc[0])
# Out:
# Tokenized örnek: ['major', 'small', 'large', 'bowel', 'procedures', 'with', 'complications', 'comorbidities']

# %%
# Stop Word Removal
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def remove_stopwords(tokens):
    return [t for t in tokens if t not in stop_words]

df_birlesik["no_stopwords"] = df_birlesik["tokens"].apply(remove_stopwords)

# Örnek
print("Stopword çıkarı:", df_birlesik["no_stopwords"].iloc[0])
# Out:
# Stopword çıkarı: ['major', 'small', 'large', 'bowel', 'procedures', 'complications', 'comorbidities']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

def lemmatize(tokens):
    return [lemmatizer.lemmatize(t) for t in tokens]

df_birlesik["lemmatized"] = df_birlesik["no_stopwords"].apply(lemmatize)

# Örnek
print("Lemmatized:", df_birlesik["lemmatized"].iloc[0])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Lemmatized: ['major', 'small', 'large', 'bowel', 'procedure', 'complication', 'comorbidities']

# %%
# Sitemming
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

def stem(tokens):
    return [stemmer.stem(t) for t in tokens]

df_birlesik["stemmed"] = df_birlesik["no_stopwords"].apply(stem)

# Örnek
print("Stemmed:", df_birlesik["stemmed"].iloc[0])
# Out:
# Stemmed: ['major', 'small', 'larg', 'bowel', 'procedur', 'complic', 'comorbid']

# %%
# Önişlenmiş verileri Tekrar string'e çevirerek kaydet
df_birlesik["lemmatized_text"] = df_birlesik["lemmatized"].apply(lambda x: " ".join(x))
df_birlesik["stemmed_text"] = df_birlesik["stemmed"].apply(lambda x: " ".join(x))

df_birlesik[["description", "lemmatized_text"]].to_csv("lemmatized.csv", index=False)
df_birlesik[["description", "stemmed_text"]].to_csv("stemmed.csv", index=False)

# %%
# lemmatized.csv Zipf Grafiği ve Değerlendirme
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')

# Veri yükle
lem_df = pd.read_csv("lemmatized.csv")

# Tüm metinleri birleştir ve tokenize et
all_text = " ".join(lem_df["lemmatized_text"].astype(str).tolist())
tokens = word_tokenize(all_text)
tokens = [t for t in tokens if t.isalpha()]

# Frekans sayımı
freq = Counter(tokens)
sorted_freq = sorted(freq.values(), reverse=True)

# Zipf log-log grafiği
ranks = np.arange(1, len(sorted_freq) + 1)
frequencies = np.array(sorted_freq)

plt.figure(figsize=(8,6))
plt.loglog(ranks, frequencies, marker=".")
plt.title("Zipf Yasası Log-Log Grafiği - Lemmatized")
plt.xlabel("Kelime Sırası (Rank)")
plt.ylabel("Frekans")
plt.grid(True, which="both", linestyle="--")
plt.tight_layout()
plt.show()

print(f"Toplam metin sayısı: {len(lem_df)}")
print(f"Toplam kelime sayısı: {len(tokens)}")
print(f"Eşsiz kelime sayısı: {len(freq)}")

if len(tokens) < 1000:
    print("Veri seti küçük sayılır. Zipf analizi sınırlı bilgi sağlayabilir.")
else:
    print("Veri seti Zipf analizi için yeterlidir.")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Toplam metin sayısı: 297
# Toplam kelime sayısı: 1505
# Eşsiz kelime sayısı: 218
# Veri seti Zipf analizi için yeterlidir.

# %%
# stemmed.csv Zipf Grafiği ve Değerlendirme
# Veri yükle
stem_df = pd.read_csv("stemmed.csv")

# Tüm metinleri birleştir ve tokenize et
all_text = " ".join(stem_df["stemmed_text"].astype(str).tolist())
tokens = word_tokenize(all_text)
tokens = [t for t in tokens if t.isalpha()]

# Frekans sayımı
freq = Counter(tokens)
sorted_freq = sorted(freq.values(), reverse=True)

# Zipf log-log grafiği
ranks = np.arange(1, len(sorted_freq) + 1)
frequencies = np.array(sorted_freq)

plt.figure(figsize=(8,6))
plt.loglog(ranks, frequencies, marker=".")
plt.title("Zipf Yasası Log-Log Grafiği - Stemmed")
plt.xlabel("Kelime Sırası (Rank)")
plt.ylabel("Frekans")
plt.grid(True, which="both", linestyle="--")
plt.tight_layout()
plt.show()

print(f"Toplam metin sayısı: {len(stem_df)}")
print(f"Toplam kelime sayısı: {len(tokens)}")
print(f"Eşsiz kelime sayısı: {len(freq)}")

if len(tokens) < 1000:
    print("Veri seti küçük sayılır. Zipf analizi sınırlı bilgi sağlayabilir.")
else:
    print("Veri seti Zipf analizi için yeterlidir.")
# Out:
# Toplam metin sayısı: 297
# Toplam kelime sayısı: 1505
# Eşsiz kelime sayısı: 213
# Veri seti Zipf analizi için yeterlidir.

# %%
# Lemmatized TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# Lemmatized veri yükle
lem_df = pd.read_csv("lemmatized.csv")

# Boş (NaN) satırları temizle
lem_df["lemmatized_text"] = lem_df["lemmatized_text"].fillna("")

# TF-IDF hesapla
vectorizer_lem = TfidfVectorizer()
X_lem = vectorizer_lem.fit_transform(lem_df["lemmatized_text"])

# Kaydet
tfidf_lem_df = pd.DataFrame(X_lem.toarray(), columns=vectorizer_lem.get_feature_names_out())
tfidf_lem_df.to_csv("tfidf_lemmatized.csv", index=False)

# %%
# Stemmed TF-IDF
# Stemmed veri yükle
stem_df = pd.read_csv("stemmed.csv")

# Boş (NaN) satırları temizle
stem_df["stemmed_text"] = stem_df["stemmed_text"].fillna("")

# TF-IDF hesapla
vectorizer_stem = TfidfVectorizer()
X_stem = vectorizer_stem.fit_transform(stem_df["stemmed_text"])

# Kaydet
tfidf_stem_df = pd.DataFrame(X_stem.toarray(), columns=vectorizer_stem.get_feature_names_out())
tfidf_stem_df.to_csv("tfidf_stemmed.csv", index=False)

# %%
# Word2Vec Parametre Setleri ve Eğitim Döngüsü
from gensim.models import Word2Vec
import pandas as pd
import os

# Klasör oluşturulmamışsa oluştur
os.makedirs("models", exist_ok=True)

# 🧪 Parametre kombinasyonları (8 adet)
parameters = [
    {'model_type': 'cbow', 'window': 2, 'vector_size': 100},
    {'model_type': 'skipgram', 'window': 2, 'vector_size': 100},
    {'model_type': 'cbow', 'window': 4, 'vector_size': 100},
    {'model_type': 'skipgram', 'window': 4, 'vector_size': 100},
    {'model_type': 'cbow', 'window': 2, 'vector_size': 300},
    {'model_type': 'skipgram', 'window': 2, 'vector_size': 300},
    {'model_type': 'cbow', 'window': 4, 'vector_size': 300},
    {'model_type': 'skipgram', 'window': 4, 'vector_size': 300},
]

# Her veri tipi için ayrı ayrı (lemmatized, stemmed)
for mode in ["lemmatized", "stemmed"]:
    path = f"{mode}.csv"
    df = pd.read_csv(path)
    
    text_col = f"{mode}_text"
    df[text_col] = df[text_col].fillna("")
    sentences = df[text_col].apply(lambda x: x.split()).tolist()

    for params in parameters:
        model_type = params["model_type"]
        sg = 1 if model_type == "skipgram" else 0
        window = params["window"]
        vector_size = params["vector_size"]

        # Model ismi örneği: word2vec_lemmatized_cbow_win2_dim100.model
        model_name = f"word2vec_{mode}_{model_type}_win{window}_dim{vector_size}"
        model_path = f"./models/{model_name}.model"

        print(f"\n Model eğitiliyor: {model_name}")

        #  Eğitim
        model = Word2Vec(
            sentences=sentences,
            vector_size=vector_size,
            window=window,
            sg=sg,
            min_count=1
        )

        # Kaydet
        model.save(model_path)
        print(f" Kaydedildi: {model_path}")

        # Örnek kelime benzerliği
        try:
            print(f"'heart' kelimesine en benzer 5 kelime:")
            for word, score in model.wv.most_similar("heart", topn=5):
                print(f" - {word}: {score:.4f}")
        except KeyError:
            print("'heart' kelimesi modelde bulunamadı.")
# Out:
#  Model eğitiliyor: word2vec_lemmatized_cbow_win2_dim100
#  Kaydedildi: ./models/word2vec_lemmatized_cbow_win2_dim100.model
# 'heart' kelimesine en benzer 5 kelime:
#  - orthopedic: 0.3198
#  - cva: 0.2895
#  - injury: 0.1986
#  - contusion: 0.1965
#  - device: 0.1839
#
#  Model eğitiliyor: word2vec_lemmatized_skipgram_win2_dim100
#  Kaydedildi: ./models/word2vec_lemmatized_skipgram_win2_dim100.model
# 'heart' kelimesine en benzer 5 kelime:
#  - orthopedic: 0.3218
#  - cva: 0.3080
#  - occulusion: 0.2023
#  - injury: 0.1996
#  - contusion: 0.1963
#
#  Model eğitiliyor: word2vec_lemmatized_cbow_win4_dim100
#  Kaydedildi: ./models/word2vec_lemmatized_cbow_win4_dim100.model
# 'heart' kelimesine en benzer 5 kelime:
#  - orthopedic: 0.3195
#  - cva: 0.2947
#  - injury: 0.1983
#  - contusion: 0.1937
#  - device: 0.1887
#
#  Model eğitiliyor: word2vec_lemmatized_skipgram_win4_dim100
#  Kaydedildi: ./models/word2vec_lemmatized_skipgram_win4_dim100.model
# 'heart' kelimesine en benzer 5 kelime:
#  - cva: 0.3590
#  - orthopedic: 0.3212
#  - without: 0.2816
#  - w: 0.2813
#  - device: 0.2688
#
#  Model eğitiliyor: word2vec_lemmatized_cbow_win2_dim300
#  Kaydedildi: ./models/word2vec_lemmatized_cbow_win2_dim300.model
# 'heart' kelimesine en benzer 5 kelime:
#  - tiss: 0.2055
#  - skin: 0.1636
#  - hip: 0.1468
#  - symptom: 0.1410
#  - hour: 0.1333
#
#  Model eğitiliyor: word2vec_lemmatized_skipgram_win2_dim300
#  Kaydedildi: ./models/word2vec_lemmatized_skipgram_win2_dim300.model
# 'heart' kelimesine en benzer 5 kelime:
#  - tiss: 0.2180
#  - skin: 0.1871
#  - hip: 0.1859
#  - symptom: 0.1622
#  - hour: 0.1597
#
#  Model eğitiliyor: word2vec_lemmatized_cbow_win4_dim300
#  Kaydedildi: ./models/word2vec_lemmatized_cbow_win4_dim300.model
# 'heart' kelimesine en benzer 5 kelime:
#  - tiss: 0.2141
#  - skin: 0.1751
#  - hip: 0.1607
#  - symptom: 0.1497
#  - hour: 0.1394
#
#  Model eğitiliyor: word2vec_lemmatized_skipgram_win4_dim300
#  Kaydedildi: ./models/word2vec_lemmatized_skipgram_win4_dim300.model
# 'heart' kelimesine en benzer 5 kelime:
#  - skin: 0.2892
#  - cardiac: 0.2810
#  - hip: 0.2761
#  - tiss: 0.2530
#  - w: 0.2430
#
#  Model eğitiliyor: word2vec_stemmed_cbow_win2_dim100
#  Kaydedildi: ./models/word2vec_stemmed_cbow_win2_dim100.model
# 'heart' kelimesine en benzer 5 kelime:
#  - ischem: 0.3147
#  - exc: 0.2649
#  - bowel: 0.2071
#  - genitourinari: 0.1964
#  - mcc: 0.1932
#
#  Model eğitiliyor: word2vec_stemmed_skipgram_win2_dim100
#  Kaydedildi: ./models/word2vec_stemmed_skipgram_win2_dim100.model
# 'heart' kelimesine en benzer 5 kelime:
#  - ischem: 0.3244
#  - exc: 0.2892
#  - bowel: 0.2182
#  - mcc: 0.2133
#  - genitourinari: 0.2090
#
#  Model eğitiliyor: word2vec_stemmed_cbow_win4_dim100
#  Kaydedildi: ./models/word2vec_stemmed_cbow_win4_dim100.model
# 'heart' kelimesine en benzer 5 kelime:
#  - ischem: 0.3213
#  - exc: 0.2697
#  - bowel: 0.2084
#  - mcc: 0.2030
#  - genitourinari: 0.2013
#
#  Model eğitiliyor: word2vec_stemmed_skipgram_win4_dim100
#  Kaydedildi: ./models/word2vec_stemmed_skipgram_win4_dim100.model
# 'heart' kelimesine en benzer 5 kelime:
#  - ischem: 0.3764
#  - exc: 0.3354
#  - mcc: 0.2955
#  - reaction: 0.2519
#  - hip: 0.2491
#
#  Model eğitiliyor: word2vec_stemmed_cbow_win2_dim300
#  Kaydedildi: ./models/word2vec_stemmed_cbow_win2_dim300.model
# 'heart' kelimesine en benzer 5 kelime:
#  - upper: 0.1655
#  - mcc: 0.1378
#  - support: 0.1347
#  - cath: 0.1280
#  - effus: 0.1279
#
#  Model eğitiliyor: word2vec_stemmed_skipgram_win2_dim300
#  Kaydedildi: ./models/word2vec_stemmed_skipgram_win2_dim300.model
# 'heart' kelimesine en benzer 5 kelime:
#  - upper: 0.1795
#  - mcc: 0.1752
#  - trauma: 0.1496
#  - cath: 0.1496
#  - support: 0.1485
#
#  Model eğitiliyor: word2vec_stemmed_cbow_win4_dim300
#  Kaydedildi: ./models/word2vec_stemmed_cbow_win4_dim300.model
# 'heart' kelimesine en benzer 5 kelime:
#  - upper: 0.1710
#  - mcc: 0.1556
#  - trauma: 0.1392
#  - support: 0.1387
#  - cath: 0.1351
#
#  Model eğitiliyor: word2vec_stemmed_skipgram_win4_dim300
#  Kaydedildi: ./models/word2vec_stemmed_skipgram_win4_dim300.model
# 'heart' kelimesine en benzer 5 kelime:
#  - mcc: 0.2908
#  - w: 0.2555
#  - face: 0.2487
#  - trauma: 0.2396
#  - major: 0.2355

# %%
df = pd.read_csv("cleaned_descriptions.csv").dropna().reset_index(drop=True)

# İlk 10 açıklamayı gösterelim
for i in range(5):
    print(f"Satır {i}:\n{df['description'].iloc[i]}\n")
# Out:
# Satır 0:
# MAJOR SMALL & LARGE BOWEL PROCEDURES WITH COMPLICATIONS, COMORBIDITIES
#
# Satır 1:
# PERCUTANEOUS CARDIOVASCULAR PROCEDURES WITHOUT ACUTE MYOCARDIAL INFARCTION, WITHOUT CORONARY ARTERY STENT IMPLANT
#
# Satır 2:
# DENTAL & ORAL DIS EXCEPT EXTRACTIONS & RESTORATIONS AGE >
#
# Satır 3:
# CRANIOTOMY AGE > EXCEPT FOR TRAUMA
#
# Satır 4:
# DISORDERS OF LIVER EXCEPT MALIGNANCY, CIRRHOSIS, ALCOHOLIC HEPATITIS WITH COMPLICATIONS, COMORBIDITIES

# %%
metin_sec = 0
input_index = df["description"].iloc[metin_sec]
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def preprocess_lemma(text):
    tokens = word_tokenize(text.lower())
    tokens = [lemmatizer.lemmatize(t) for t in tokens if t.isalpha() and t not in stop_words]
    return " ".join(tokens)

giris_metni = preprocess_lemma(input_index)
print("Seçilen giriş metni:")
print(giris_metni)
# Out:
# Seçilen giriş metni:
# major small large bowel procedure complication comorbidities

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# 1. Veri setini yükle
df = pd.read_csv("lemmatized.csv")
df["lemmatized_text"] = df["lemmatized_text"].fillna("")

# 2. TF-IDF modeli
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df["lemmatized_text"])

# 3. Giriş metni: seçilen metin

input_vec = tfidf_matrix[metin_sec]
input_text = df["lemmatized_text"].iloc[metin_sec]

# 4. Cosine similarity tüm veri ile
cosine_sim = cosine_similarity(input_vec, tfidf_matrix)[0]

# 5. En benzer 5 metni bul (kendisi dahil olur)
top5_idx = cosine_sim.argsort()[-5:][::-1]

# 6. Giriş metnindeki anahtar kelimeleri belirle
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def get_keywords(text):
    tokens = word_tokenize(text.lower())
    tokens = [lemmatizer.lemmatize(t) for t in tokens if t.isalpha() and t not in stop_words]
    return sorted(set(tokens))

keywords = get_keywords(input_text)

# 7. Kelime - Metin TF-IDF skorlarını topla
word_index = vectorizer.vocabulary_
score_matrix = {}

for word in keywords:
    row = []
    if word in word_index:
        col_idx = word_index[word]
        for i in top5_idx:
            row.append(round(tfidf_matrix[i, col_idx], 2))
    else:
        row = [0.0] * 5
    score_matrix[word] = row

# 8. Tablo olarak göster
columns = [f"Metin {i+1}" for i in range(5)]
tfidf_keyword_table = pd.DataFrame.from_dict(score_matrix, orient="index", columns=columns)
tfidf_keyword_table
# Out:
#                Metin 1  Metin 2  Metin 3  Metin 4  Metin 5
# bowel             0.46     0.52     0.52     0.50     0.00
# comorbidities     0.34     0.00     0.00     0.00     0.31
# complication      0.32     0.00     0.00     0.00     0.29
# large             0.46     0.52     0.52     0.50     0.00
# major             0.30     0.35     0.35     0.33     0.28
# procedure         0.22     0.25     0.25     0.24     0.20
# small             0.46     0.52     0.52     0.50     0.00

# %%
# 1. Veri setini yükle
df = pd.read_csv("stemmed.csv")
df["stemmed_text"] = df["stemmed_text"].fillna("")

# 2. TF-IDF modeli
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df["stemmed_text"])

# 3. Giriş metni: secilen metin

input_vec = tfidf_matrix[metin_sec]
input_text = df["stemmed_text"].iloc[metin_sec]

# 4. Cosine similarity hesapla
cosine_sim = cosine_similarity(input_vec, tfidf_matrix)[0]
top5_idx = cosine_sim.argsort()[-5:][::-1]

# 5. Anahtar kelimeleri bul (stopwords + stemming)
stop_words = set(stopwords.words("english"))
stemmer = PorterStemmer()

def get_keywords_stem(text):
    tokens = word_tokenize(text.lower())
    tokens = [stemmer.stem(t) for t in tokens if t.isalpha() and t not in stop_words]
    return sorted(set(tokens))

keywords = get_keywords_stem(input_text)

# 6. Skor tablosu oluştur
word_index = vectorizer.vocabulary_
score_matrix = {}

for word in keywords:
    row = []
    if word in word_index:
        col_idx = word_index[word]
        for i in top5_idx:
            row.append(round(tfidf_matrix[i, col_idx], 2))
    else:
        row = [0.0] * 5
    score_matrix[word] = row

# 7. Tabloyu göster
columns = [f"Metin {i+1}" for i in range(5)]
tfidf_stemmed_table = pd.DataFrame.from_dict(score_matrix, orient="index", columns=columns)
tfidf_stemmed_table
# Out:
#           Metin 1  Metin 2  Metin 3  Metin 4  Metin 5
# bowel        0.46     0.52     0.52     0.50     0.00
# comorbid     0.34     0.00     0.00     0.00     0.31
# complic      0.32     0.00     0.00     0.00     0.29
# larg         0.46     0.52     0.52     0.50     0.00
# major        0.31     0.35     0.35     0.33     0.28
# procedur     0.22     0.25     0.25     0.24     0.20
# small        0.46     0.52     0.52     0.50     0.00

# %%
from gensim.models import Word2Vec
from numpy.linalg import norm
from nltk.stem import WordNetLemmatizer, PorterStemmer
import os

# %%
# Stopwords ve önişleme araçları
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# Giriş metni
def preprocess(text, mode):
    tokens = word_tokenize(text.lower())
    tokens = [t for t in tokens if t.isalpha() and t not in stop_words]
    if mode == "lemmatized":
        return [lemmatizer.lemmatize(t) for t in tokens]
    else:
        return [stemmer.stem(t) for t in tokens]

input_vectors = {}
input_tokens_dict = {}

# Giriş metni her mod için önceden hazırlanıyor
for mode in ["lemmatized", "stemmed"]:
    input_tokens = preprocess(input_text, mode)

    def sentence_vector(tokens, model):
        vectors = [model.wv[w] for w in tokens if w in model.wv]
        return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

    input_tokens_dict[mode] = input_tokens
    input_vectors[mode] = sentence_vector(input_tokens, Word2Vec(min_count=1, vector_size=100))  # geçici, sonra overwrite olacak

# Tüm modelleri sırayla işle
model_dir = "./models/"
model_files = [f for f in os.listdir(model_dir) if f.endswith(".model") and f.startswith("word2vec_")]

for model_file in sorted(model_files):
    model_path = os.path.join(model_dir, model_file)
    model = Word2Vec.load(model_path)

    # Model parametrelerini dosya isminden al
    parts = model_file.replace("./models/.model", "").split("_")
    mode = parts[1]        # lemmatized veya stemmed
    model_type = parts[2]  # cbow veya skipgram
    window = parts[3]
    dim = parts[4]

    # Veri yükle
    df = pd.read_csv(f"{mode}.csv")
    df[f"{mode}_text"] = df[f"{mode}_text"].fillna("")
    sentences = df[f"{mode}_text"].apply(lambda x: x.split()).tolist()

    # Giriş metni vektörü
    input_vec = sentence_vector(input_tokens_dict[mode], model)

    # Benzerlikleri hesapla
    similarities = []
    for tokens in sentences:
        vec = sentence_vector(tokens, model)
        sim = np.dot(input_vec, vec) / (norm(input_vec) * norm(vec)) if norm(vec) > 0 else 0
        similarities.append(sim)

    # En benzer 5 metni bul
    top5 = np.argsort(similarities)[-5:][::-1]

    # Başlık
    print(f"\n Model: {mode} | {model_type.upper()} | {window} | {dim}")
    for i in top5:
        print(f" Skor: {similarities[i]:.4f} - {df[f'{mode}_text'].iloc[i][:100]}...")
# Out:
#  Model: lemmatized | CBOW | win2 | dim100.model
#  Skor: 0.7076 - major small large bowel procedure...
#  Skor: 0.7076 - major small large bowel procedure...
#  Skor: 0.6216 - major small large bowel procedure complication comorbidities...
#  Skor: 0.6054 - major small large bowel procedure w mcc...
#  Skor: 0.4257 - major joint limb reattachment procedure upper extremity...
#
#  Model: lemmatized | CBOW | win2 | dim300.model
#  Skor: 0.6352 - major small large bowel procedure...
#  Skor: 0.6352 - major small large bowel procedure...
#  Skor: 0.5349 - major small large bowel procedure w mcc...
#  Skor: 0.5214 - major small large bowel procedure complication comorbidities...
#  Skor: 0.2996 - hepatic coma major acute liver disorder...
#
#  Model: lemmatized | CBOW | win4 | dim100.model
#  Skor: 0.7145 - major small large bowel procedure...
#  Skor: 0.7145 - major small large bowel procedure...
#  Skor: 0.6314 - major small large bowel procedure complication comorbidities...
#  Skor: 0.6144 - major small large bowel procedure w mcc...
#  Skor: 0.4437 - major joint limb reattachment procedure upper extremity...
#
#  Model: lemmatized | CBOW | win4 | dim300.model
#  Skor: 0.6441 - major small large bowel procedure...
#  Skor: 0.6441 - major small large bowel procedure...
#  Skor: 0.5460 - major small large bowel procedure w mcc...
#  Skor: 0.5342 - major small large bowel procedure complication comorbidities...
#  Skor: 0.3198 - major joint replacement reattachment lower extremity wo mcc...
#
#  Model: lemmatized | SKIPGRAM | win2 | dim100.model
#  Skor: 0.7641 - major small large bowel procedure...
#  Skor: 0.7641 - major small large bowel procedure...
#  Skor: 0.6962 - major small large bowel procedure complication comorbidities...
#  Skor: 0.6874 - major small large bowel procedure w mcc...
#  Skor: 0.5363 - major joint limb reattachment procedure upper extremity...
#
#  Model: lemmatized | SKIPGRAM | win2 | dim300.model
#  Skor: 0.6932 - major small large bowel procedure...
#  Skor: 0.6932 - major small large bowel procedure...
#  Skor: 0.6169 - major small large bowel procedure w mcc...
#  Skor: 0.6022 - major small large bowel procedure complication comorbidities...
#  Skor: 0.4134 - major joint replacement reattachment lower extremity wo mcc...
#
#  Model: lemmatized | SKIPGRAM | win4 | dim100.model
#  Skor: 0.8145 - major small large bowel procedure...
#  Skor: 0.8145 - major small large bowel procedure...
#  Skor: 0.7640 - major small large bowel procedure complication comorbidities...
#  Skor: 0.7538 - major small large bowel procedure w mcc...
#  Skor: 0.6500 - major joint limb reattachment procedure upper extremity...
#
#  Model: lemmatized | SKIPGRAM | win4 | dim300.model
#  Skor: 0.7628 - major small large bowel procedure...
#  Skor: 0.7628 - major small large bowel procedure...
#  Skor: 0.7044 - major small large bowel procedure w mcc...
#  Skor: 0.6988 - major small large bowel procedure complication comorbidities...
#  Skor: 0.5653 - major joint replacement reattachment lower extremity wo mcc...
#
#  Model: stemmed | CBOW | win2 | dim100.model
#  Skor: 1.0000 - major small larg bowel procedur complic comorbid...
#  Skor: 0.8462 - major small larg bowel procedur...
#  Skor: 0.8462 - major small larg bowel procedur...
#  Skor: 0.7630 - major small larg bowel procedur w mcc...
#  Skor: 0.5535 - hip femur procedur except major joint age complic comorbid...
#
#  Model: stemmed | CBOW | win2 | dim300.model
#  Skor: 1.0000 - major small larg bowel procedur complic comorbid...
#  Skor: 0.8591 - major small larg bowel procedur...
#  Skor: 0.8591 - major small larg bowel procedur...
#  Skor: 0.7773 - major small larg bowel procedur w mcc...
#  Skor: 0.5764 - hip femur procedur except major joint age complic comorbid...
#
#  Model: stemmed | CBOW | win4 | dim100.model
#  Skor: 1.0000 - major small larg bowel procedur complic comorbid...
#  Skor: 0.8544 - major small larg bowel procedur...
#  Skor: 0.8544 - major small larg bowel procedur...
#  Skor: 0.7828 - major small larg bowel procedur w mcc...
#  Skor: 0.5946 - hip femur procedur except major joint age complic comorbid...
#
#  Model: stemmed | CBOW | win4 | dim300.model
#  Skor: 1.0000 - major small larg bowel procedur complic comorbid...
#  Skor: 0.8694 - major small larg bowel procedur...
#  Skor: 0.8694 - major small larg bowel procedur...
#  Skor: 0.7992 - major small larg bowel procedur w mcc...
#  Skor: 0.6200 - hip femur procedur except major joint age complic comorbid...
#
#  Model: stemmed | SKIPGRAM | win2 | dim100.model
#  Skor: 1.0000 - major small larg bowel procedur complic comorbid...
#  Skor: 0.8797 - major small larg bowel procedur...
#  Skor: 0.8797 - major small larg bowel procedur...
#  Skor: 0.8315 - major small larg bowel procedur w mcc...
#  Skor: 0.6768 - hip femur procedur except major joint age complic comorbid...
#
#  Model: stemmed | SKIPGRAM | win2 | dim300.model
#  Skor: 1.0000 - major small larg bowel procedur complic comorbid...
#  Skor: 0.8915 - major small larg bowel procedur...
#  Skor: 0.8915 - major small larg bowel procedur...
#  Skor: 0.8418 - major small larg bowel procedur w mcc...
#  Skor: 0.6941 - hip femur procedur except major joint age complic comorbid...
#
#  Model: stemmed | SKIPGRAM | win4 | dim100.model
#  Skor: 1.0000 - major small larg bowel procedur complic comorbid...
#  Skor: 0.9199 - major small larg bowel procedur...
#  Skor: 0.9199 - major small larg bowel procedur...
#  Skor: 0.8989 - major small larg bowel procedur w mcc...
#  Skor: 0.8091 - hip femur procedur except major joint age complic comorbid...
#
#  Model: stemmed | SKIPGRAM | win4 | dim300.model
#  Skor: 1.0000 - major small larg bowel procedur complic comorbid...
#  Skor: 0.9283 - major small larg bowel procedur...
#  Skor: 0.9283 - major small larg bowel procedur...
#  Skor: 0.9091 - major small larg bowel procedur w mcc...
#  Skor: 0.8224 - hip femur procedur except major joint age complic comorbid...

# %%
# Giriş metni indexi (veri setindeki satır numarası)
input_index = metin_sec

# Klasörler
model_dir = r"C:\Users\eren\Desktop\ömer ödev\models"
data_dir = r"C:\Users\eren\Desktop\ömer ödev\data"

# Ortak araçlar
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

def preprocess(text, mode):
    tokens = word_tokenize(text.lower())
    tokens = [t for t in tokens if t.isalpha() and t not in stop_words]
    return [lemmatizer.lemmatize(t) if mode == "lemmatized" else stemmer.stem(t) for t in tokens]

def sentence_vector(tokens, model):
    vectors = [model.wv[w] for w in tokens if w in model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

# TF-IDF Modelleri
tfidf_results = []
def tfidf_model_score(mode):
    text_col = f"{mode}_text"
    data_path = os.path.join(data_dir, f"{mode}.csv")

    try:
        df = pd.read_csv(data_path)
        df[text_col] = df[text_col].fillna("")
    except Exception as e:
        print(f" TF-IDF veri hatası: {e}")
        return None

    corpus = df[text_col].tolist()
    input_text = df[text_col].iloc[input_index]

    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(corpus)
    input_vec = vectorizer.transform([input_text])

    similarities = cosine_similarity(input_vec, tfidf_matrix)[0]

    # Giriş metninin kendisini tespit et ve eşleşmesini sıfırla
    for i, text in enumerate(corpus):
        if text.strip() == input_text.strip():
            similarities[i] = 0.0

    top5_idx = similarities.argsort()[-5:][::-1]
    top5_texts = [corpus[i] for i in top5_idx]
    top5_preview = " | ".join([text[:50] + "..." for text in top5_texts])

    return {
        "Model Adı": f"tfidf_{mode}",
        "5 Benzer Metin": top5_preview,
        "Ortalama Skor": round(np.mean(similarities), 2),
        "En Yüksek Skor": round(np.max(similarities), 2),
    }

# TF-IDF için skorları hesapla
for mode in ["lemmatized", "stemmed"]:
    res = tfidf_model_score(mode)
    if res:
        tfidf_results.append(res)

# Word2Vec Modelleri
word2vec_results = []

model_files = [f for f in os.listdir(model_dir) if f.endswith(".model")]
pattern = r"word2vec_(lemmatized|stemmed)_(cbow|skipgram)_win(\d+)_dim(\d+)\.model"

for model_file in sorted(model_files):
    match = re.match(pattern, model_file)
    if not match:
        print(f" Geçersiz model formatı: {model_file}")
        continue

    mode, model_type, window, dim = match.groups()
    text_col = f"{mode}_text"
    data_path = os.path.join(data_dir, f"{mode}.csv")
    model_path = os.path.join(model_dir, model_file)

    try:
        df = pd.read_csv(data_path)
        df[text_col] = df[text_col].fillna("")
    except:
        continue

    try:
        model = Word2Vec.load(model_path)
    except:
        continue

    sentences = df[text_col].tolist()
    input_text = sentences[input_index]
    input_tokens = preprocess(input_text, mode)
    input_vec = sentence_vector(input_tokens, model)

    if np.all(input_vec == 0):
        continue

    similarities = []
    for i, sentence in enumerate(sentences):
        tokens = preprocess(sentence, mode)
        vec = sentence_vector(tokens, model)

        sim = np.dot(input_vec, vec) / (norm(input_vec) * norm(vec)) if norm(vec) > 0 else 0

        # Aynı cümleyse benzerliği sıfırla
        if sentence.strip() == input_text.strip():
            sim = 0.0

        similarities.append(sim)

    similarities = np.array(similarities)
    top5_idx = similarities.argsort()[-5:][::-1]
    top5_texts = [sentences[i] for i in top5_idx]
    top5_preview = " | ".join([text[:50] + "..." for text in top5_texts])

    word2vec_results.append({
        "Model Adı": model_file.replace(".model", ""),
        "5 Benzer Metin": top5_preview,
        "Ortalama Skor": round(np.mean(similarities), 2),
        "En Yüksek Skor": round(np.max(similarities), 2),
    })

# Tüm sonuçları birleştir
all_results = tfidf_results + word2vec_results
comparison_df = pd.DataFrame(all_results)
comparison_df["is_tfidf"] = comparison_df["Model Adı"].str.contains("tfidf", case=False)
comparison_df = comparison_df.sort_values(by=["is_tfidf", "En Yüksek Skor"], ascending=[False, False])
comparison_df = comparison_df.drop(columns=["is_tfidf"]).reset_index(drop=True)

# Sonuçları göster
comparison_df
# Out:
#  Geçersiz model formatı: lemmatized_model_cbow_vs100_w2.model
#  Geçersiz model formatı: lemmatized_model_cbow_vs100_w4.model
#  Geçersiz model formatı: lemmatized_model_cbow_vs300_w2.model
#  Geçersiz model formatı: lemmatized_model_cbow_vs300_w4.model
#  Geçersiz model formatı: lemmatized_model_skipgram_vs100_w2.model
#  Geçersiz model formatı: lemmatized_model_skipgram_vs100_w4.model
#  Geçersiz model formatı: lemmatized_model_skipgram_vs300_w2.model
#  Geçersiz model formatı: lemmatized_model_skipgram_vs300_w4.model
#  Geçersiz model formatı: stemmed_model_cbow_vs100_w2.model
#  Geçersiz model formatı: stemmed_model_cbow_vs100_w4.model
#  Geçersiz model formatı: stemmed_model_cbow_vs300_w2.model
#  Geçersiz model formatı: stemmed_model_cbow_vs300_w4.model
#  Geçersiz model formatı: stemmed_model_skipgram_vs100_w2.model
#  Geçersiz model formatı: stemmed_model_skipgram_vs100_w4.model
#  Geçersiz model formatı: stemmed_model_skipgram_vs300_w2.model
#  Geçersiz model formatı: stemmed_model_skipgram_vs300_w4.model
#                                    Model Adı  \
# 0                              tfidf_stemmed
# 1                           tfidf_lemmatized
# 2   word2vec_lemmatized_skipgram_win4_dim100
# 3      word2vec_stemmed_skipgram_win4_dim300
# 4   word2vec_lemmatized_skipgram_win4_dim300
# 5      word2vec_stemmed_skipgram_win4_dim100
# 6   word2vec_lemmatized_skipgram_win2_dim100
# 7   word2vec_lemmatized_skipgram_win2_dim300
# 8      word2vec_stemmed_skipgram_win2_dim300
# 9      word2vec_stemmed_skipgram_win2_dim100
# 10         word2vec_stemmed_cbow_win4_dim300
# 11      word2vec_lemmatized_cbow_win4_dim100
# 12      word2vec_lemmatized_cbow_win4_dim300
# 13         word2vec_stemmed_cbow_win2_dim300
# 14      word2vec_lemmatized_cbow_win2_dim100
# 15      word2vec_lemmatized_cbow_win2_dim300
# 16         word2vec_stemmed_cbow_win2_dim100
# 17         word2vec_stemmed_cbow_win4_dim100
#
#                                        5 Benzer Metin  Ortalama Skor  \
# 0   major small larg bowel procedur... | major sma...           0.05
# 1   major small large bowel procedure... | major s...           0.04
# 2   major small large bowel procedure... | major s...           0.51
# 3   major small larg bowel procedur... | major sma...           0.50
# 4   major small large bowel procedure... | major s...           0.52
# 5   major small larg bowel procedur... | major sma...           0.48
# 6   major small large bowel procedure... | major s...           0.33
# 7   major small large bowel procedure... | major s...           0.34
# 8   major small larg bowel procedur... | major sma...           0.32
# 9   major small larg bowel procedur... | major sma...           0.31
# 10  major small larg bowel procedur... | major sma...           0.23
# 11  major small large bowel procedure... | major s...           0.21
# 12  major small large bowel procedure... | major s...           0.23
# 13  major small larg bowel procedur... | major sma...           0.18
# 14  major small large bowel procedure... | major s...           0.18
# 15  major small large bowel procedure... | major s...           0.19
# 16  major small larg bowel procedur... | major sma...           0.17
# 17  major small larg bowel procedur... | major sma...           0.20
#
#     En Yüksek Skor
# 0             0.89
# 1             0.88
# 2             0.93
# 3             0.93
# 4             0.92
# 5             0.92
# 6             0.89
# 7             0.89
# 8             0.89
# 9             0.88
# 10            0.87
# 11            0.86
# 12            0.86
# 13            0.86
# 14            0.85
# 15            0.85
# 16            0.85
# 17            0.85

# %%
# Ön işleme fonksiyonu
def preprocess(text, mode):
    tokens = word_tokenize(text.lower())
    tokens = [t for t in tokens if t.isalpha() and t not in stop_words]
    return [lemmatizer.lemmatize(t) if mode == "lemmatized" else stemmer.stem(t) for t in tokens]

# Ortalama vektör
def sentence_vector(tokens, model):
    vectors = [model.wv[w] for w in tokens if w in model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

# Jaccard skoru hesapla
def jaccard_score(set1, set2):
    set1, set2 = set(set1), set(set2)
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return round(intersection / union, 2) if union > 0 else 0.0

# Tüm modellerin ilk 5 benzer metin indexlerini topla
top5_dict = {}

### TF-IDF MODELLERİ
for mode in ["lemmatized", "stemmed"]:
    text_col = f"{mode}_text"
    data_path = os.path.join(data_dir, f"{mode}.csv")
    df = pd.read_csv(data_path)
    df[text_col] = df[text_col].fillna("")
    corpus = df[text_col].tolist()

    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(corpus)
    input_vec = tfidf_matrix[input_index]
    similarities = cosine_similarity(input_vec, tfidf_matrix)[0]
    similarities[input_index] = 0  # kendisiyle eşleşmeyi dışla

    top5_idx = similarities.argsort()[-5:][::-1].tolist()
    top5_dict[f"tfidf_{mode}"] = top5_idx

### WORD2VEC MODELLERİ
model_files = [f for f in os.listdir(model_dir) if f.endswith(".model")]
pattern = r"word2vec_(lemmatized|stemmed)_(cbow|skipgram)_win(\d+)_dim(\d+)\.model"

for model_file in sorted(model_files):
    match = re.match(pattern, model_file)
    if not match:
        continue

    mode, model_type, window, dim = match.groups()
    model_path = os.path.join(model_dir, model_file)
    text_col = f"{mode}_text"
    data_path = os.path.join(data_dir, f"{mode}.csv")

    df = pd.read_csv(data_path)
    df[text_col] = df[text_col].fillna("")
    sentences = df[text_col].apply(lambda x: x.split()).tolist()
    input_text = df[text_col].iloc[input_index]
    input_tokens = preprocess(input_text, mode)

    try:
        model = Word2Vec.load(model_path)
    except:
        continue

    input_vec = sentence_vector(input_tokens, model)
    if np.all(input_vec == 0):
        continue

    similarities = []
    for tokens in sentences:
        vec = sentence_vector(tokens, model)
        sim = np.dot(input_vec, vec) / (np.linalg.norm(input_vec) * np.linalg.norm(vec)) if np.linalg.norm(vec) > 0 else 0
        similarities.append(sim)

    similarities = np.array(similarities)
    similarities[input_index] = 0  # kendisiyle eşleşmeyi dışla
    top5_idx = similarities.argsort()[-5:][::-1].tolist()

    model_name = model_file.replace(".model", "")
    top5_dict[model_name] = top5_idx

# Jaccard skor matrisi oluştur
model_names = list(top5_dict.keys())
jaccard_matrix = pd.DataFrame(index=model_names, columns=model_names)

for model1 in model_names:
    for model2 in model_names:
        jaccard_matrix.loc[model1, model2] = jaccard_score(top5_dict[model1], top5_dict[model2])

# Skorları float olarak göster
jaccard_matrix = jaccard_matrix.astype(float)
jaccard_matrix
# Out:
#                                           tfidf_lemmatized  tfidf_stemmed  \
# tfidf_lemmatized                                      1.00           1.00
# tfidf_stemmed                                         1.00           1.00
# word2vec_lemmatized_cbow_win2_dim100                  0.67           0.67
# word2vec_lemmatized_cbow_win2_dim300                  0.67           0.67
# word2vec_lemmatized_cbow_win4_dim100                  0.67           0.67
# word2vec_lemmatized_cbow_win4_dim300                  0.67           0.67
# word2vec_lemmatized_skipgram_win2_dim100              0.67           0.67
# word2vec_lemmatized_skipgram_win2_dim300              0.67           0.67
# word2vec_lemmatized_skipgram_win4_dim100              0.67           0.67
# word2vec_lemmatized_skipgram_win4_dim300              0.67           0.67
# word2vec_stemmed_cbow_win2_dim100                     0.67           0.67
# word2vec_stemmed_cbow_win2_dim300                     0.67           0.67
# word2vec_stemmed_cbow_win4_dim100                     0.67           0.67
# word2vec_stemmed_cbow_win4_dim300                     0.67           0.67
# word2vec_stemmed_skipgram_win2_dim100                 0.67           0.67
# word2vec_stemmed_skipgram_win2_dim300                 0.67           0.67
# word2vec_stemmed_skipgram_win4_dim100                 0.67           0.67
# word2vec_stemmed_skipgram_win4_dim300                 0.67           0.67
#
#                                           word2vec_lemmatized_cbow_win2_dim100  \
# tfidf_lemmatized                                                          0.67
# tfidf_stemmed                                                             0.67
# word2vec_lemmatized_cbow_win2_dim100                                      1.00
# word2vec_lemmatized_cbow_win2_dim300                                      0.67
# word2vec_lemmatized_cbow_win4_dim100                                      1.00
# word2vec_lemmatized_cbow_win4_dim300                                      0.67
# word2vec_lemmatized_skipgram_win2_dim100                                  1.00
# word2vec_lemmatized_skipgram_win2_dim300                                  0.67
# word2vec_lemmatized_skipgram_win4_dim100                                  1.00
# word2vec_lemmatized_skipgram_win4_dim300                                  0.67
# word2vec_stemmed_cbow_win2_dim100                                         0.67
# word2vec_stemmed_cbow_win2_dim300                                         0.67
# word2vec_stemmed_cbow_win4_dim100                                         0.67
# word2vec_stemmed_cbow_win4_dim300                                         0.67
# word2vec_stemmed_skipgram_win2_dim100                                     0.67
# word2vec_stemmed_skipgram_win2_dim300                                     0.67
# word2vec_stemmed_skipgram_win4_dim100                                     0.67
# word2vec_stemmed_skipgram_win4_dim300                                     0.67
#
#                                           word2vec_lemmatized_cbow_win2_dim300  \
# tfidf_lemmatized                                                          0.67
# tfidf_stemmed                                                             0.67
# word2vec_lemmatized_cbow_win2_dim100                                      0.67
# word2vec_lemmatized_cbow_win2_dim300                                      1.00
# word2vec_lemmatized_cbow_win4_dim100                                      0.67
# word2vec_lemmatized_cbow_win4_dim300                                      1.00
# word2vec_lemmatized_skipgram_win2_dim100                                  0.67
# word2vec_lemmatized_skipgram_win2_dim300                                  1.00
# word2vec_lemmatized_skipgram_win4_dim100                                  0.67
# word2vec_lemmatized_skipgram_win4_dim300                                  1.00
# word2vec_stemmed_cbow_win2_dim100                                         1.00
# word2vec_stemmed_cbow_win2_dim300                                         0.67
# word2vec_stemmed_cbow_win4_dim100                                         1.00
# word2vec_stemmed_cbow_win4_dim300                                         0.67
# word2vec_stemmed_skipgram_win2_dim100                                     1.00
# word2vec_stemmed_skipgram_win2_dim300                                     0.67
# word2vec_stemmed_skipgram_win4_dim100                                     1.00
# word2vec_stemmed_skipgram_win4_dim300                                     0.67
#
#                                           word2vec_lemmatized_cbow_win4_dim100  \
# tfidf_lemmatized                                                          0.67
# tfidf_stemmed                                                             0.67
# word2vec_lemmatized_cbow_win2_dim100                                      1.00
# word2vec_lemmatized_cbow_win2_dim300                                      0.67
# word2vec_lemmatized_cbow_win4_dim100                                      1.00
# word2vec_lemmatized_cbow_win4_dim300                                      0.67
# word2vec_lemmatized_skipgram_win2_dim100                                  1.00
# word2vec_lemmatized_skipgram_win2_dim300                                  0.67
# word2vec_lemmatized_skipgram_win4_dim100                                  1.00
# word2vec_lemmatized_skipgram_win4_dim300                                  0.67
# word2vec_stemmed_cbow_win2_dim100                                         0.67
# word2vec_stemmed_cbow_win2_dim300                                         0.67
# word2vec_stemmed_cbow_win4_dim100                                         0.67
# word2vec_stemmed_cbow_win4_dim300                                         0.67
# word2vec_stemmed_skipgram_win2_dim100                                     0.67
# word2vec_stemmed_skipgram_win2_dim300                                     0.67
# word2vec_stemmed_skipgram_win4_dim100                                     0.67
# word2vec_stemmed_skipgram_win4_dim300                                     0.67
#
#                                           word2vec_lemmatized_cbow_win4_dim300  \
# tfidf_lemmatized                                                          0.67
# tfidf_stemmed                                                             0.67
# word2vec_lemmatized_cbow_win2_dim100                                      0.67
# word2vec_lemmatized_cbow_win2_dim300                                      1.00
# word2vec_lemmatized_cbow_win4_dim100                                      0.67
# word2vec_lemmatized_cbow_win4_dim300                                      1.00
# word2vec_lemmatized_skipgram_win2_dim100                                  0.67
# word2vec_lemmatized_skipgram_win2_dim300                                  1.00
# word2vec_lemmatized_skipgram_win4_dim100                                  0.67
# word2vec_lemmatized_skipgram_win4_dim300                                  1.00
# word2vec_stemmed_cbow_win2_dim100                                         1.00
# word2vec_stemmed_cbow_win2_dim300                                         0.67
# word2vec_stemmed_cbow_win4_dim100                                         1.00
# word2vec_stemmed_cbow_win4_dim300                                         0.67
# word2vec_stemmed_skipgram_win2_dim100                                     1.00
# word2vec_stemmed_skipgram_win2_dim300                                     0.67
# word2vec_stemmed_skipgram_win4_dim100                                     1.00
# word2vec_stemmed_skipgram_win4_dim300                                     0.67
#
#                                           word2vec_lemmatized_skipgram_win2_dim100  \
# tfidf_lemmatized                                                              0.67
# tfidf_stemmed                                                                 0.67
# word2vec_lemmatized_cbow_win2_dim100                                          1.00
# word2vec_lemmatized_cbow_win2_dim300                                          0.67
# word2vec_lemmatized_cbow_win4_dim100                                          1.00
# word2vec_lemmatized_cbow_win4_dim300                                          0.67
# word2vec_lemmatized_skipgram_win2_dim100                                      1.00
# word2vec_lemmatized_skipgram_win2_dim300                                      0.67
# word2vec_lemmatized_skipgram_win4_dim100                                      1.00
# word2vec_lemmatized_skipgram_win4_dim300                                      0.67
# word2vec_stemmed_cbow_win2_dim100                                             0.67
# word2vec_stemmed_cbow_win2_dim300                                             0.67
# word2vec_stemmed_cbow_win4_dim100                                             0.67
# word2vec_stemmed_cbow_win4_dim300                                             0.67
# word2vec_stemmed_skipgram_win2_dim100                                         0.67
# word2vec_stemmed_skipgram_win2_dim300                                         0.67
# word2vec_stemmed_skipgram_win4_dim100                                         0.67
# word2vec_stemmed_skipgram_win4_dim300                                         0.67
#
#                                           word2vec_lemmatized_skipgram_win2_dim300  \
# tfidf_lemmatized                                                              0.67
# tfidf_stemmed                                                                 0.67
# word2vec_lemmatized_cbow_win2_dim100                                          0.67
# word2vec_lemmatized_cbow_win2_dim300                                          1.00
# word2vec_lemmatized_cbow_win4_dim100                                          0.67
# word2vec_lemmatized_cbow_win4_dim300                                          1.00
# word2vec_lemmatized_skipgram_win2_dim100                                      0.67
# word2vec_lemmatized_skipgram_win2_dim300                                      1.00
# word2vec_lemmatized_skipgram_win4_dim100                                      0.67
# word2vec_lemmatized_skipgram_win4_dim300                                      1.00
# word2vec_stemmed_cbow_win2_dim100                                             1.00
# word2vec_stemmed_cbow_win2_dim300                                             0.67
# word2vec_stemmed_cbow_win4_dim100                                             1.00
# word2vec_stemmed_cbow_win4_dim300                                             0.67
# word2vec_stemmed_skipgram_win2_dim100                                         1.00
# word2vec_stemmed_skipgram_win2_dim300                                         0.67
# word2vec_stemmed_skipgram_win4_dim100                                         1.00
# word2vec_stemmed_skipgram_win4_dim300                                         0.67
#
#                                           word2vec_lemmatized_skipgram_win4_dim100  \
# tfidf_lemmatized                                                              0.67
# tfidf_stemmed                                                                 0.67
# word2vec_lemmatized_cbow_win2_dim100                                          1.00
# word2vec_lemmatized_cbow_win2_dim300                                          0.67
# word2vec_lemmatized_cbow_win4_dim100                                          1.00
# word2vec_lemmatized_cbow_win4_dim300                                          0.67
# word2vec_lemmatized_skipgram_win2_dim100                                      1.00
# word2vec_lemmatized_skipgram_win2_dim300                                      0.67
# word2vec_lemmatized_skipgram_win4_dim100                                      1.00
# word2vec_lemmatized_skipgram_win4_dim300                                      0.67
# word2vec_stemmed_cbow_win2_dim100                                             0.67
# word2vec_stemmed_cbow_win2_dim300                                             0.67
# word2vec_stemmed_cbow_win4_dim100                                             0.67
# word2vec_stemmed_cbow_win4_dim300                                             0.67
# word2vec_stemmed_skipgram_win2_dim100                                         0.67
# word2vec_stemmed_skipgram_win2_dim300                                         0.67
# word2vec_stemmed_skipgram_win4_dim100                                         0.67
# word2vec_stemmed_skipgram_win4_dim300                                         0.67
#
#                                           word2vec_lemmatized_skipgram_win4_dim300  \
# tfidf_lemmatized                                                              0.67
# tfidf_stemmed                                                                 0.67
# word2vec_lemmatized_cbow_win2_dim100                                          0.67
# word2vec_lemmatized_cbow_win2_dim300                                          1.00
# word2vec_lemmatized_cbow_win4_dim100                                          0.67
# word2vec_lemmatized_cbow_win4_dim300                                          1.00
# word2vec_lemmatized_skipgram_win2_dim100                                      0.67
# word2vec_lemmatized_skipgram_win2_dim300                                      1.00
# word2vec_lemmatized_skipgram_win4_dim100                                      0.67
# word2vec_lemmatized_skipgram_win4_dim300                                      1.00
# word2vec_stemmed_cbow_win2_dim100                                             1.00
# word2vec_stemmed_cbow_win2_dim300                                             0.67
# word2vec_stemmed_cbow_win4_dim100                                             1.00
# word2vec_stemmed_cbow_win4_dim300                                             0.67
# word2vec_stemmed_skipgram_win2_dim100                                         1.00
# word2vec_stemmed_skipgram_win2_dim300                                         0.67
# word2vec_stemmed_skipgram_win4_dim100                                         1.00
# word2vec_stemmed_skipgram_win4_dim300                                         0.67
#
#                                           word2vec_stemmed_cbow_win2_dim100  \
# tfidf_lemmatized                                                       0.67
# tfidf_stemmed                                                          0.67
# word2vec_lemmatized_cbow_win2_dim100                                   0.67
# word2vec_lemmatized_cbow_win2_dim300                                   1.00
# word2vec_lemmatized_cbow_win4_dim100                                   0.67
# word2vec_lemmatized_cbow_win4_dim300                                   1.00
# word2vec_lemmatized_skipgram_win2_dim100                               0.67
# word2vec_lemmatized_skipgram_win2_dim300                               1.00
# word2vec_lemmatized_skipgram_win4_dim100                               0.67
# word2vec_lemmatized_skipgram_win4_dim300                               1.00
# word2vec_stemmed_cbow_win2_dim100                                      1.00
# word2vec_stemmed_cbow_win2_dim300                                      0.67
# word2vec_stemmed_cbow_win4_dim100                                      1.00
# word2vec_stemmed_cbow_win4_dim300                                      0.67
# word2vec_stemmed_skipgram_win2_dim100                                  1.00
# word2vec_stemmed_skipgram_win2_dim300                                  0.67
# word2vec_stemmed_skipgram_win4_dim100                                  1.00
# word2vec_stemmed_skipgram_win4_dim300                                  0.67
#
#                                           word2vec_stemmed_cbow_win2_dim300  \
# tfidf_lemmatized                                                       0.67
# tfidf_stemmed                                                          0.67
# word2vec_lemmatized_cbow_win2_dim100                                   0.67
# word2vec_lemmatized_cbow_win2_dim300                                   0.67
# word2vec_lemmatized_cbow_win4_dim100                                   0.67
# word2vec_lemmatized_cbow_win4_dim300                                   0.67
# word2vec_lemmatized_skipgram_win2_dim100                               0.67
# word2vec_lemmatized_skipgram_win2_dim300                               0.67
# word2vec_lemmatized_skipgram_win4_dim100                               0.67
# word2vec_lemmatized_skipgram_win4_dim300                               0.67
# word2vec_stemmed_cbow_win2_dim100                                      0.67
# word2vec_stemmed_cbow_win2_dim300                                      1.00
# word2vec_stemmed_cbow_win4_dim100                                      0.67
# word2vec_stemmed_cbow_win4_dim300                                      1.00
# word2vec_stemmed_skipgram_win2_dim100                                  0.67
# word2vec_stemmed_skipgram_win2_dim300                                  1.00
# word2vec_stemmed_skipgram_win4_dim100                                  0.67
# word2vec_stemmed_skipgram_win4_dim300                                  1.00
#
#                                           word2vec_stemmed_cbow_win4_dim100  \
# tfidf_lemmatized                                                       0.67
# tfidf_stemmed                                                          0.67
# word2vec_lemmatized_cbow_win2_dim100                                   0.67
# word2vec_lemmatized_cbow_win2_dim300                                   1.00
# word2vec_lemmatized_cbow_win4_dim100                                   0.67
# word2vec_lemmatized_cbow_win4_dim300                                   1.00
# word2vec_lemmatized_skipgram_win2_dim100                               0.67
# word2vec_lemmatized_skipgram_win2_dim300                               1.00
# word2vec_lemmatized_skipgram_win4_dim100                               0.67
# word2vec_lemmatized_skipgram_win4_dim300                               1.00
# word2vec_stemmed_cbow_win2_dim100                                      1.00
# word2vec_stemmed_cbow_win2_dim300                                      0.67
# word2vec_stemmed_cbow_win4_dim100                                      1.00
# word2vec_stemmed_cbow_win4_dim300                                      0.67
# word2vec_stemmed_skipgram_win2_dim100                                  1.00
# word2vec_stemmed_skipgram_win2_dim300                                  0.67
# word2vec_stemmed_skipgram_win4_dim100                                  1.00
# word2vec_stemmed_skipgram_win4_dim300                                  0.67
#
#                                           word2vec_stemmed_cbow_win4_dim300  \
# tfidf_lemmatized                                                       0.67
# tfidf_stemmed                                                          0.67
# word2vec_lemmatized_cbow_win2_dim100                                   0.67
# word2vec_lemmatized_cbow_win2_dim300                                   0.67
# word2vec_lemmatized_cbow_win4_dim100                                   0.67
# word2vec_lemmatized_cbow_win4_dim300                                   0.67
# word2vec_lemmatized_skipgram_win2_dim100                               0.67
# word2vec_lemmatized_skipgram_win2_dim300                               0.67
# word2vec_lemmatized_skipgram_win4_dim100                               0.67
# word2vec_lemmatized_skipgram_win4_dim300                               0.67
# word2vec_stemmed_cbow_win2_dim100                                      0.67
# word2vec_stemmed_cbow_win2_dim300                                      1.00
# word2vec_stemmed_cbow_win4_dim100                                      0.67
# word2vec_stemmed_cbow_win4_dim300                                      1.00
# word2vec_stemmed_skipgram_win2_dim100                                  0.67
# word2vec_stemmed_skipgram_win2_dim300                                  1.00
# word2vec_stemmed_skipgram_win4_dim100                                  0.67
# word2vec_stemmed_skipgram_win4_dim300                                  1.00
#
#                                           word2vec_stemmed_skipgram_win2_dim100  \
# tfidf_lemmatized                                                           0.67
# tfidf_stemmed                                                              0.67
# word2vec_lemmatized_cbow_win2_dim100                                       0.67
# word2vec_lemmatized_cbow_win2_dim300                                       1.00
# word2vec_lemmatized_cbow_win4_dim100                                       0.67
# word2vec_lemmatized_cbow_win4_dim300                                       1.00
# word2vec_lemmatized_skipgram_win2_dim100                                   0.67
# word2vec_lemmatized_skipgram_win2_dim300                                   1.00
# word2vec_lemmatized_skipgram_win4_dim100                                   0.67
# word2vec_lemmatized_skipgram_win4_dim300                                   1.00
# word2vec_stemmed_cbow_win2_dim100                                          1.00
# word2vec_stemmed_cbow_win2_dim300                                          0.67
# word2vec_stemmed_cbow_win4_dim100                                          1.00
# word2vec_stemmed_cbow_win4_dim300                                          0.67
# word2vec_stemmed_skipgram_win2_dim100                                      1.00
# word2vec_stemmed_skipgram_win2_dim300                                      0.67
# word2vec_stemmed_skipgram_win4_dim100                                      1.00
# word2vec_stemmed_skipgram_win4_dim300                                      0.67
#
#                                           word2vec_stemmed_skipgram_win2_dim300  \
# tfidf_lemmatized                                                           0.67
# tfidf_stemmed                                                              0.67
# word2vec_lemmatized_cbow_win2_dim100                                       0.67
# word2vec_lemmatized_cbow_win2_dim300                                       0.67
# word2vec_lemmatized_cbow_win4_dim100                                       0.67
# word2vec_lemmatized_cbow_win4_dim300                                       0.67
# word2vec_lemmatized_skipgram_win2_dim100                                   0.67
# word2vec_lemmatized_skipgram_win2_dim300                                   0.67
# word2vec_lemmatized_skipgram_win4_dim100                                   0.67
# word2vec_lemmatized_skipgram_win4_dim300                                   0.67
# word2vec_stemmed_cbow_win2_dim100                                          0.67
# word2vec_stemmed_cbow_win2_dim300                                          1.00
# word2vec_stemmed_cbow_win4_dim100                                          0.67
# word2vec_stemmed_cbow_win4_dim300                                          1.00
# word2vec_stemmed_skipgram_win2_dim100                                      0.67
# word2vec_stemmed_skipgram_win2_dim300                                      1.00
# word2vec_stemmed_skipgram_win4_dim100                                      0.67
# word2vec_stemmed_skipgram_win4_dim300                                      1.00
#
#                                           word2vec_stemmed_skipgram_win4_dim100  \
# tfidf_lemmatized                                                           0.67
# tfidf_stemmed                                                              0.67
# word2vec_lemmatized_cbow_win2_dim100                                       0.67
# word2vec_lemmatized_cbow_win2_dim300                                       1.00
# word2vec_lemmatized_cbow_win4_dim100                                       0.67
# word2vec_lemmatized_cbow_win4_dim300                                       1.00
# word2vec_lemmatized_skipgram_win2_dim100                                   0.67
# word2vec_lemmatized_skipgram_win2_dim300                                   1.00
# word2vec_lemmatized_skipgram_win4_dim100                                   0.67
# word2vec_lemmatized_skipgram_win4_dim300                                   1.00
# word2vec_stemmed_cbow_win2_dim100                                          1.00
# word2vec_stemmed_cbow_win2_dim300                                          0.67
# word2vec_stemmed_cbow_win4_dim100                                          1.00
# word2vec_stemmed_cbow_win4_dim300                                          0.67
# word2vec_stemmed_skipgram_win2_dim100                                      1.00
# word2vec_stemmed_skipgram_win2_dim300                                      0.67
# word2vec_stemmed_skipgram_win4_dim100                                      1.00
# word2vec_stemmed_skipgram_win4_dim300                                      0.67
#
#                                           word2vec_stemmed_skipgram_win4_dim300
# tfidf_lemmatized                                                           0.67
# tfidf_stemmed                                                              0.67
# word2vec_lemmatized_cbow_win2_dim100                                       0.67
# word2vec_lemmatized_cbow_win2_dim300                                       0.67
# word2vec_lemmatized_cbow_win4_dim100                                       0.67
# word2vec_lemmatized_cbow_win4_dim300                                       0.67
# word2vec_lemmatized_skipgram_win2_dim100                                   0.67
# word2vec_lemmatized_skipgram_win2_dim300                                   0.67
# word2vec_lemmatized_skipgram_win4_dim100                                   0.67
# word2vec_lemmatized_skipgram_win4_dim300                                   0.67
# word2vec_stemmed_cbow_win2_dim100                                          0.67
# word2vec_stemmed_cbow_win2_dim300                                          1.00
# word2vec_stemmed_cbow_win4_dim100                                          0.67
# word2vec_stemmed_cbow_win4_dim300                                          1.00
# word2vec_stemmed_skipgram_win2_dim100                                      0.67
# word2vec_stemmed_skipgram_win2_dim300                                      1.00
# word2vec_stemmed_skipgram_win4_dim100                                      0.67
# word2vec_stemmed_skipgram_win4_dim300                                      1.00
